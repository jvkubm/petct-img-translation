# %%
import torch
import numpy as np
import torch.nn as nn

# %%
input = torch.randn(1,1,64,64,64)
input.shape
# Out:
# torch.Size([1, 1, 64, 64, 64])

# %%
m = nn.MaxPool3d(2, stride=2)
output = m(input)
print(output.shape)
# Out:
# torch.Size([1, 1, 32, 32, 32])

# %%
in_channels = 1
features = 64
c = nn.Conv3d(in_channels=in_channels, out_channels=features, kernel_size=3, padding=1, bias=False)
output = c(input)
print(output.shape)
output
# Out:
# torch.Size([1, 64, 64, 64, 64])
# tensor([[[[[ 2.6280e-01, -4.1291e-02,  2.6690e-02,  ...,  2.6555e-01,
#              2.4444e-01,  3.3915e-01],
#            [-2.8618e-01,  1.6983e-01,  7.4174e-01,  ..., -8.1493e-02,
#             -5.9111e-01, -4.6080e-01],
#            [-8.4746e-02,  2.8776e-01, -2.3724e-01,  ..., -5.5804e-02,
#              2.9563e-01,  3.2328e-01],
#            ...,
#            [-5.5017e-02,  4.9277e-01,  9.4406e-02,  ...,  2.5771e-01,
#             -1.0899e-01,  2.3959e-01],
#            [-3.9955e-01, -2.0376e-01, -2.9194e-01,  ...,  1.8124e-01,
#              3.8266e-02,  6.5688e-02],
#            [-6.5338e-01,  4.5862e-01,  6.4894e-02,  ..., -1.9410e-01,
#             -1.6639e-01,  4.7695e-01]],
#
#           [[ 7.5731e-02, -6.5558e-01, -2.0956e-02,  ...,  2.5763e-01,
#             -7.1129e-01, -6.3133e-01],
#            [-3.6463e-01,  5.5581e-01, -4.6507e-01,  ..., -2.4313e-01,
#              4.1877e-01,  7.5137e-01],
# ...

# %%
in_channels = 1
features = 64
c = nn.Conv3d(in_channels=in_channels, out_channels=features, kernel_size=3, padding=1, bias=False, dilation=)
output = c(input)
print(output.shape)
output

# %%
input = torch.randn(1,512,64,64,64)
print(input.shape)
ct = nn.ConvTranspose3d(features * 8, features * 4, kernel_size=2, stride=2)
output = ct(input)
# Out:
# torch.Size([1, 512, 64, 64, 64])

# %%
output.shape
# Out:
# torch.Size([1, 256, 128, 128, 128])
